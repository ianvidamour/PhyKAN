# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import os
import matplotlib.pyplot as plt
# Out:
# /home/ian/anaconda3/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/ian/anaconda3/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
path = os.getcwd()+'/Loss Data/'
shape = [6, 5, 5, 5, 1]
name = 'Large'
PT_losses = np.zeros((4, 1000))
T_losses = np.zeros((4, 1000))
P_losses = np.zeros((4, 1000))
base_losses = np.zeros((4, 1000))
for i in range(4):
        PT_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        P_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=False, run='+str(i)+'.npy', allow_pickle=True))
        T_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        base_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=False, run='+str(i)+'.npy', allow_pickle=True))
PT_losses[np.isnan(PT_losses)] =  0
P_losses[np.isnan(P_losses)] =  0
T_losses[np.isnan(T_losses)] =  0
base_losses[np.isnan(base_losses)] =  0

plt.figure()
plt.yscale('log')
plt.title('Network Size [6, 5, 5, 5, 1]')
plt.plot(np.arange(0, 1000000, 1000), PT_losses.mean(axis=0).T, label='Penalty and Thresholding')
plt.plot(np.arange(0, 1000000, 1000), P_losses.mean(axis=0).T, label='Penalty Only')
plt.plot(np.arange(0, 1000000, 1000), T_losses.mean(axis=0).T, label='Thresholding Only')
plt.plot(np.arange(0, 1000000, 1000), base_losses.mean(axis=0).T, label='Neither')
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.legend()
plt.show()

path = os.getcwd()+'/Loss Data/'
shape = [6, 2, 2, 1]
name = 'Small'
PT_losses = np.zeros((10, 1000))
T_losses = np.zeros((10, 1000))
P_losses = np.zeros((10, 1000))
base_losses = np.zeros((10, 1000))
for i in range(10):
        PT_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        P_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=False, run='+str(i)+'.npy', allow_pickle=True))
        T_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        base_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=False, run='+str(i)+'.npy', allow_pickle=True))

PT_losses[np.isnan(PT_losses)] =  0
P_losses[np.isnan(P_losses)] =  0
T_losses[np.isnan(T_losses)] =  0
base_losses[np.isnan(base_losses)] =  0


plt.figure()
plt.yscale('log')
plt.title('Network Size [6, 2, 2, 1]')
plt.plot(np.arange(0, 1000000, 1000), PT_losses.mean(axis=0).T, label='Penalty and Thresholding')
plt.plot(np.arange(0, 1000000, 1000), P_losses.mean(axis=0).T, label='Penalty Only')
plt.plot(np.arange(0, 1000000, 1000), T_losses.mean(axis=0).T, label='Thresholding Only')
plt.plot(np.arange(0, 1000000, 1000), base_losses.mean(axis=0).T, label='Neither')
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.legend()
plt.show()

path = os.getcwd()+'/Loss Data/'
shape = [6, 4, 2, 1, 1]
name = 'Tailored'
PT_losses = np.zeros((10, 1000))
T_losses = np.zeros((10, 1000))
P_losses = np.zeros((10, 1000))
base_losses = np.zeros((10, 1000))
for i in range(7):
        PT_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        P_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=True, threshold=False, run='+str(i)+'.npy', allow_pickle=True))
        T_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=True, run='+str(i)+'.npy', allow_pickle=True))
        base_losses[i, :] = np.asarray(np.load(path+'Loss, shape='+str(name)+', penalty=False, threshold=False, run='+str(i)+'.npy', allow_pickle=True))

PT_losses[np.isnan(PT_losses)] =  0
P_losses[np.isnan(P_losses)] =  0
T_losses[np.isnan(T_losses)] =  0
base_losses[np.isnan(base_losses)] =  0


plt.figure()
plt.yscale('log')
plt.title('Network Size [6, 4, 2, 1, 1]')
plt.plot(np.arange(0, 1000000, 1000), PT_losses.mean(axis=0).T, label='Penalty and Thresholding')
plt.plot(np.arange(0, 1000000, 1000), P_losses.mean(axis=0).T, label='Penalty Only')
plt.plot(np.arange(0, 1000000, 1000), T_losses.mean(axis=0).T, label='Thresholding Only')
plt.plot(np.arange(0, 1000000, 1000), base_losses.mean(axis=0).T, label='Neither')
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.legend()
plt.show()

# %%
path = os.getcwd()+'/Weight Data/'
shape = [6, 2, 2, 1]
name = 'Small'
i=0
PT_ws = np.load(path+'Weights, shape='+str(name)+', penalty=True, threshold=True, run='+str(i)+'.npy', allow_pickle=True)
P_ws = np.load(path+'Weights, shape='+str(name)+', penalty=True, threshold=False, run='+str(i)+'.npy', allow_pickle=True)
T_ws = np.load(path+'Weights, shape='+str(name)+', penalty=False, threshold=True, run='+str(i)+'.npy', allow_pickle=True)
base_ws = np.load(path+'Weights, shape='+str(name)+', penalty=False, threshold=False, run='+str(i)+'.npy', allow_pickle=True)

l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][0])
l1_ws = np.asarray(l1_ws)
l1_ws.shape
# Out:
# (1000, 6, 2, 6, 3)

# %%
def band_pass_single(Xin, params, threshold):
    # Threshold input
    Xin = (Xin-threshold).relu()
    # Bound parameters
    params=params.sigmoid()
    # Normalise input of 0-1 to frequencies of 100 Hz-100 kHz
    freq = 10**(3.69+2*Xin).unsqueeze(-1).unsqueeze(-1)
    # For 'sensible' initialisation, we'd like parameters that make sense for gain, f_low, and f_high:
    # Set gain between +/- 5X
    gain = 10*(params[:, 0].unsqueeze(0)-0.5)
    # Set cutoff frequencies between 10 Hz and 1 MHz
    fc_low = 10+(10**(0.5+5*params[:, 1].unsqueeze(0)))
    fc_high = 10+(10**(0.5+5*params[:, 2].unsqueeze(0)))
    RC_low = (2*torch.pi*fc_low)**-1
    RC_high = (2*torch.pi*fc_high)**-1
    Hout = gain*torch.abs((2j*torch.pi*freq*RC_low/(1+2j*torch.pi*freq*RC_low))*(1/(1+2j*torch.pi*freq*RC_high)))
    return Hout.sum(dim=1).sum(dim=-1)

xin = torch.linspace(0, 1, 1000)
import matplotlib as mpl

n_lines = 1000
cmap = mpl.colormaps['inferno_r']

# Take colors at regular intervals spanning the colormap.
colors = cmap(np.linspace(0, 1, n_lines))
for nodein in range(6):
    for nodeout in range(2):
        plt.figure()
        plt.title('Layer 0, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

# %%
l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][1])
l1_ws = np.asarray(l1_ws)
l1_ws.shape
# Take colors at regular intervals spanning the colormap.
colors = cmap(np.linspace(0, 1, n_lines))
for nodein in range(2):
    for nodeout in range(2):
        plt.figure()
        plt.title('Layer 1, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

# %%
l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][2])
l1_ws = np.asarray(l1_ws)
l1_ws.shape
# Take colors at regular intervals spanning the colormap.
colors = cmap(np.linspace(0, 1, n_lines))
for nodein in range(2):
    for nodeout in range(1):
        plt.figure()
        plt.title('Layer 2, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

# %% [markdown]
# ## Looking at these graphs, there are two major issues:
# ##    - The early layer seems not to change at all. Perhaps this is due to vanishing gradients from all the bounding with sigmoids.
# ##    - The corner frequencies don't seem to change much from initialised parameters. Looking at the mathematics for the gradient descent, the gradient values are still tiny! My initial fix seems not to have properly alleviated the problem, just improved the inititialisation.
#
# ## Additionally, from the loss curves, the penalty term seems to improve peak performance considerably for smaller networks. The weight data is still running and will be processed soon.

# %%
path = os.getcwd()+'/Weight Data/'
shape = [6, 4, 2, 1, 1]
name = 'Tailored'
i=0
PT_ws = np.load(path+'Weights, shape='+str(name)+', penalty=True, threshold=True, run='+str(i)+'.npy', allow_pickle=True)
P_ws = np.load(path+'Weights, shape='+str(name)+', penalty=True, threshold=False, run='+str(i)+'.npy', allow_pickle=True)
T_ws = np.load(path+'Weights, shape='+str(name)+', penalty=False, threshold=True, run='+str(i)+'.npy', allow_pickle=True)
base_ws = np.load(path+'Weights, shape='+str(name)+', penalty=False, threshold=False, run='+str(i)+'.npy', allow_pickle=True)

l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][0])
l1_ws = np.asarray(l1_ws)
l1_ws.shape
for nodein in range(6):
    for nodeout in range(4):
        plt.figure()
        plt.title('Layer 0, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][1])
l1_ws = np.asarray(l1_ws)
l1_ws.shape

for nodein in range(4):
    for nodeout in range(2):
        plt.figure()
        plt.title('Layer 1, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][2])
l1_ws = np.asarray(l1_ws)
l1_ws.shape

for nodein in range(2):
    for nodeout in range(1):
        plt.figure()
        plt.title('Layer 2, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()

l1_ws = []
for i in range(1000):
    l1_ws.append(base_ws[i][3])
l1_ws = np.asarray(l1_ws)
l1_ws.shape

for nodein in range(1):
    for nodeout in range(1):
        plt.figure()
        plt.title('Layer 3, Npre'+str(nodein)+', Npost'+str(nodeout))
        for i in range(1000):
            params = torch.from_numpy(l1_ws[i, nodein, nodeout])
            output = band_pass_single(xin, params, 0)
            plt.plot(xin, output, alpha=0.75, color=colors[i])
        plt.show()
